# %%
# !pip uninstall openai -y
# !pip install git+https://github.com/OpenGPTs-platform/openai-python

# %%
from openai import OpenAI
import json

client = OpenAI(
    base_url="http://localhost:8000",
    api_key="api_key",
)

# %%
# create assistant
assistant = client.beta.assistants.create(
    instructions="""You empersonate Daniel based on the information in the file my_information.txt .""",
    model="phi3:medium"
)
# create thread
thread = client.beta.threads.create(
    messages=[
        {
            "role": "user",
            "content": "Concisely tell me about Daniel from the file my_information.txt",  # noqa
        },
    ],
)
# run response generation
run = client.beta.threads.runs.create_and_poll(
    thread_id=thread.id,
    assistant_id=assistant.id,
)
# print messages
messages = client.beta.threads.messages.list(
    thread_id=thread.id, order='desc'
)
print(json.dumps(messages.model_dump(), indent=2))
# Out:
# {
#   "data": [
#     {
#       "id": "067520e2-2a3e-4592-82f0-0ef21907ebef",
#       "assistant_id": null,
#       "attachments": [],
#       "completed_at": null,
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Concisely tell me about Daniel from the file my_information.txt"
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1720983113165,
#       "incomplete_at": null,
#       "incomplete_details": null,
#       "metadata": {},
#       "object": "thread.message",
#       "role": "user",
#       "run_id": null,
#       "status": "completed",
#       "thread_id": "fb1b2516-da6c-400c-bf5e-8579cda8b1a2"
#     }
#   ]
# }

# %%
# create assistant
assistant = client.beta.assistants.create(
    instructions="""YOU MUST USE TOOLS! You empersonate Daniel based on the information in the file my_information.txt which you can obtain using the file_search tool.""",
    tools=[
        {"type": "web_retrieval"},
        {"type": "file_search"}
    ],
    tool_resources={
        "file_search": {
            "vector_store_ids": [vector_store.id]
        }
    },
    model="phi3:medium"
)
# create thread
thread = client.beta.threads.create(
    messages=[
        {
            "role": "user",
            "content": "Tell me about a recent spacex mission",  # noqa
        },
    ],
)
# run response generation
run = client.beta.threads.runs.create_and_poll(
    thread_id=thread.id,
    assistant_id=assistant.id,
)
# print messages
messages = client.beta.threads.messages.list(
    thread_id=thread.id, order='desc'
)
print(json.dumps(messages.model_dump(), indent=2))

# %%
# print messages
messages = client.beta.threads.messages.list(
    thread_id=thread.id, order='desc'
)
print(json.dumps(messages.model_dump(), indent=2))
# Out:
# {
#   "data": [
#     {
#       "id": "02d2aa9f-0b5c-431f-a078-e1485965ab3b",
#       "assistant_id": null,
#       "attachments": [],
#       "completed_at": null,
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "The web retrieval provided some information about SpaceX missions, but it doesn't specifically mention the CRS-23 mission or its scientific experiments. I should search for more specific information about the CRS-23 mission using the file search tool."
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1720934032859,
#       "incomplete_at": null,
#       "incomplete_details": null,
#       "metadata": {},
#       "object": "thread.message",
#       "role": "assistant",
#       "run_id": null,
#       "status": "completed",
#       "thread_id": "7ddaaed1-fd3c-4513-8d58-ec76f6d80ecb"
#     },
#     {
#       "id": "0a719392-e4b8-499d-bf30-8a1f1944faab",
#       "assistant_id": null,
#       "attachments": [],
#       "completed_at": null,
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "The user is asking about a recent SpaceX mission. I should retrieve information about it."
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1720934027834,
#       "incomplete_at": null,
#       "incomplete_details": null,
#       "metadata": {},
#       "object": "thread.message",
#       "role": "assistant",
#       "run_id": null,
#       "status": "completed",
#       "thread_id": "7ddaaed1-fd3c-4513-8d58-ec76f6d80ecb"
#     },
#     {
#       "id": "0f581586-c0f1-4ff6-a364-77f45fae5e33",
#       "assistant_id": null,
#       "attachments": [],
#       "completed_at": null,
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Tell me about a recent spacex mission"
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1720934022505,
#       "incomplete_at": null,
#       "incomplete_details": null,
#       "metadata": {},
#       "object": "thread.message",
#       "role": "user",
#       "run_id": null,
#       "status": "completed",
#       "thread_id": "7ddaaed1-fd3c-4513-8d58-ec76f6d80ecb"
#     }
#   ]
# }
